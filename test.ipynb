# %%
from function import *
import numpy as np
import matplotlib.pyplot as plt

# %%
v0 = 1.

params1 = parametr2( 1., 5., 3., -4., -0.8, -0.6, 0.01, 0., 10. )

params2 = parametr2( 1., 5., 3., -4., 0.0, 0.0, 0.01, 0., 10. )

# %%
uRk, tRk = runge_kutta( params1 )

uRk2, tRk2 = runge_kutta( params2 )

uAd, tAd = adams( params2, 0.5 )

# %%
plot_graph( 15, 12, [tRk, tRk2, ],
            [uRk[ :,0 ], uRk2[ :,0 ], ],
            ['-', '--' ], ['blue', 'black' ], [ r'$u_0 \neq 0$', r'$u_0 = 0$' ], r'$x(t)$' )

# %%
plot_graph( 15, 12, [tRk, tRk, tAd, tAd ],
            [uRk[ :,0 ], uRk[ :,1 ], uAd[ :, 0], uAd[ :, 1] ],
            ['-', '-', '--', '--' ], ['blue', 'green', 'red', 'black' ], [ r'метод Рунге-Кутты Ox', r'метод Рунге-Кутты Oy', r'метод Адамса Ox', r'метод Адамса Oy' ], r'$u(t)$' )

# %%
plot_graph( 10, 8, [tRk, tRk ],
            [uRk[ :,0 ], uRk[ :, 1] ],
            ['-', '-' ], ['blue', 'red' ], [ 'колебания вдоль Ох', 'колебания вдоль Оy' ] )

# %%
plot_graph( 15, 10, [tRk2, ],
            [np.sqrt(uRk2[ :,0 ] ** 2 + uRk2[ :,2 ] ** 2) - 5, ],
            ['-', ], ['blue', ], [ r'$\sqrt{x^2+y^2}-L$', ], r'$\sqrt{x^2+y^2}-L$' )

# %%
uRk[ :,0 ] ** 2 + uRk[ :,1 ] ** 2 - 5**2

# %%
p_cross = (0.0023, 451.161)

# %%
p_cross = np.zeros(2)

# %%
p_cross = 0.0023, 451.161

# %%
p_cross
# Out:
# (0.0023, 451.161)
